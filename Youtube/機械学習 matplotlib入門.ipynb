# %% [markdown]
# # matplotlib
# matplotlibはPythonにおけるデータ可視化のための代表的なライブラリ

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(0)

plt.style.use('ggplot')

# %% [markdown]
# # 基本的な２つの書き方
# matplotlibでグラフを描画するには、主に2つの方法が存在します。
#
# １つ目は簡易的な方法で、少ないコードで済みますが、あまり自由度は高くありません。
#
# 2つ目は、もう少し厳格な方法で、いろいろなカスタマイズが可能ですが、その分きちんとコードを書かなくてはなりません

# %% [markdown]
# # 簡易的な方法

# %%
x = np.linspace(0, 1, 10)
y = 2 * x + 0.1 * np.random.randn(10)
plt.plot(x, y)
plt.show()

# %% [markdown]
# # 厳格な方法

# %%
x = np.linspace(0, 1, 10)
y = 2 * x + 0.1 * np.random.randn(10)

fig = plt.figure()
ax = fig.add_subplot(111) 

ax.plot(x, y) 

plt.show()

# %% [markdown]
# figure()とadd_subplot()メソッドを使って、fig, axを生成するのが違い
#
# figはグラフを配置する領域のことで、axはグラフを描画する領域を示します。

# %% [markdown]
# # 複数のグラフを描写する

# %%
x_1 = np.linspace(0, 1, 10)
y_1 = x_1 + 0.1 * np.random.randn(10)

x_2 = np.linspace(0, 1, 100)
y_2 = 2 * x_2 + 0.1 * np.random.randn(100)

x_3 = np.linspace(0, 1, 1000)
y_3 = 3 * x_3 + 0.1 * np.random.randn(1000)

# %%
fig = plt.figure()

ax_1 = fig.add_subplot(221) 
ax_2 = fig.add_subplot(222) 
ax_3 = fig.add_subplot(223) 

ax_1.plot(x_1, y_1) 
ax_2.plot(x_2, y_2) 
ax_3.plot(x_3, y_3) 

plt.show()

# %% [markdown]
# # グラフの大きさを操作する

# %% [markdown]
# fig生成時にfigsizeを指定

# %%
fig = plt.figure(figsize=(20, 12))

ax_1 = fig.add_subplot(221) 
ax_2 = fig.add_subplot(222) 
ax_3 = fig.add_subplot(223) 

ax_1.plot(x_1, y_1) 
ax_2.plot(x_2, y_2) 
ax_3.plot(x_3, y_3) 

plt.show()

# %% [markdown]
# # 簡易版での書き方

# %%
x = np.linspace(0, 1, 10)
y = 2 * x + 0.1 * np.random.randn(10)

plt.figure(figsize=(12, 8))
plt.plot(x, y)
plt.show()

# %% [markdown]
# # figureとaxの生成を同時に行う
#
# subplots()メソッド

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 12))

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
axes.shape
# Out:
# (2, 2)

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 12))

axes[0][0].plot(x_1, y_1) 
axes[0][1].plot(x_2, y_2) 
axes[1][0].plot(x_3, y_3) 

plt.show()

# %% [markdown]
# # axesを１次元配列に変換
#
# 行の番号と列の番号どちらも指定しなくてはならない２次元配列は不便
#
# ravel()メソッドでaxesを１次元配列に変換すれば、通し番号だけでグラフ

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 12))

axes.ravel()[0].plot(x_1, y_1) 
axes.ravel()[1].plot(x_2, y_2) 
axes.ravel()[2].plot(x_3, y_3) 

plt.show()

# %% [markdown]
# # 折れ線グラフ
#
# plotメソッド
#
# 第１引数のxの値と、第２引数のｙの値

# %%
df = pd.DataFrame(data=np.random.rand(30, 2), columns=['C1', 'C2'])
df.head()
# Out:
#          C1        C2
# 0  0.221824  0.493945
# 1  0.929619  0.667215
# 2  0.798079  0.550994
# 3  0.980466  0.588662
# 4  0.045511  0.197983

# %%
plt.figure(figsize=(12, 8))
plt.plot(df['C1'])
plt.show()

# %% [markdown]
# # 複数の線を描写する

# %%
plt.figure(figsize=(12, 8))
plt.plot(df['C1'])
plt.plot(df['C2'])
plt.show()

# %% [markdown]
# # 見た目を整える
#
# # タイトル・軸・判例の設定

# %%
plt.figure(figsize=(12, 8))

plt.plot(df['C1'])
plt.plot(df['C2'])

plt.title("test", fontsize=20)
plt.xlabel('x', fontsize=15)
plt.ylabel('y', fontsize=15)

plt.legend(['data_1', 'data_2'])

plt.show()

# %% [markdown]
# # 線の色・太さ・スタイルを変更

# %%
plt.figure(figsize=(12, 8))

plt.plot(df['C1'], color='#2971e5', linewidth=5.0, linestyle='solid')
plt.plot(df['C2'], color='#ed3b3b', linewidth=5.0, linestyle='dashed')

plt.title("test", fontsize=20)
plt.xlabel('x', fontsize=15)
plt.ylabel('y', fontsize=15)

plt.legend(['data_1', 'data_2'])

plt.show()

# %% [markdown]
# # 散布図
#
# scatterメソッド

# %%
df = pd.DataFrame(data=np.random.randn(500, 2), columns=['C1', 'C2'])
df.head()
# Out:
#          C1        C2
# 0  0.018792 -0.593777
# 1 -2.011880  0.589704
# 2 -0.896370 -1.962732
# 3  1.584821  0.647968
# 4 -1.139008 -1.214401

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df['C1'], df['C2'])
plt.show()

# %% [markdown]
# # 点の大きさ・色・スタイルを変更する

# %%
plt.figure(figsize=(12, 8))

plt.scatter(df['C1'], df['C2'], s=200, c='#f7d945', marker='^', alpha=0.5)

plt.title("test", fontsize=20)
plt.xlabel('$x_0$', fontsize=15)
plt.ylabel('$x_1$', fontsize=15)

plt.show()

# %% [markdown]
# # 点の大きさや色をデータによって変える

# %%
df['data_size'] = np.random.randint(1, 100, 500)
df.head()
# Out:
#          C1        C2  data_size
# 0  0.018792 -0.593777         88
# 1 -2.011880  0.589704         43
# 2 -0.896370 -1.962732         69
# 3  1.584821  0.647968         53
# 4 -1.139008 -1.214401         72

# %%
plt.figure(figsize=(12, 8))

plt.scatter(df['C1'], df['C2'], s=df['data_size']*10, c=df['data_size'], cmap='viridis', alpha=0.8)
plt.colorbar()

plt.title("test", fontsize=20)
plt.xlabel('$x_0$', fontsize=15)
plt.ylabel('$x_1$', fontsize=15)

plt.show()

# %% [markdown]
# # 棒グラフ
#
# bar()メソッド

# %%
df = pd.DataFrame({'C1': ['A', 'A', 'A', 'B', 'B', 'C'],
                   'C2': [20, 50, 60, 80, 100, 30],
                   'C3': [40, 200, 100, 500, 40, 200,]})
df
# Out:
#   C1   C2   C3
# 0  A   20   40
# 1  A   50  200
# 2  A   60  100
# 3  B   80  500
# 4  B  100   40
# 5  C   30  200

# %%
plt.figure(figsize=(12, 8))
plt.bar(df['C1'].value_counts().index, df.groupby('C1').sum()['C2'])
plt.show()

# %% [markdown]
# # 複数の棒グラフを描画

# %%
df = pd.DataFrame(data=100 * np.random.rand(5, 5), index=['A', 'B', 'C', 'D', 'E'], 
                  columns=['C1', 'C2', 'C3', 'C4', 'C5'])
df.head()
# Out:
#           C1         C2         C3         C4         C5
# A   3.486336   7.873472  84.581161  34.608133  98.407994
# B  23.637194  90.047887  57.381632  39.338516  76.935769
# C  83.984988  31.260788  47.689061  67.567665  69.808731
# D  30.034118   9.270437  39.110502  34.470529   8.961729
# E  39.318863  57.115667  99.633730  75.700881  33.059145

# %%
plt.figure(figsize=(12, 8))

ｘ = np.arange(len(df))

bar_width = 0.4

plt.bar(x, df['C1'], color='red', width=bar_width, label='C1')
plt.bar(x + bar_width, df['C2'], color='blue', width=bar_width, label='C2')

plt.xticks(x + bar_width / 2, df.index, fontsize=20)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(16, 8))

ｘ = np.arange(len(df), dtype='float64')

bar_width = 0.1

for col in df.columns:
    plt.bar(x, df[col], width=bar_width, label=col)
    x += bar_width
    
plt.xticks((np.arange(len(df)) + x - bar_width) / 2, df.index, fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# # ヒストグラム
#
# histメソッド

# %%
df = pd.DataFrame(data=np.random.randn(500), columns=['C1'])
df.head()
# Out:
#          C1
# 0 -0.968396
# 1 -0.213583
# 2  0.290255
# 3  1.343829
# 4 -2.582447

# %%
plt.figure(figsize=(12, 8))
plt.hist(df['C1'])
plt.show()

# %% [markdown]
# # 見た目を整える
#
# ビンの数を指定するbins、棒の幅を指定しているrwidthなどを調節

# %% [markdown]
# # 正規分布曲線を描く

# %%
from scipy.stats import norm

def histogram(x, bins=20):
    plt.figure(figsize=(12, 8))
    plt.hist(x, bins=bins, rwidth=0.8, color='#63738c', density=True)
    
    mean = x.mean()
    std = x.std()
    
    X = np.linspace(x.min(), x.max(), bins)
    y = norm.pdf(X, mean, std)
    
    plt.plot(X, y, linewidth=3)
    plt.show()
    
histogram(df['C1'])

# %% [markdown]
# # 円グラフ
#
# pieメソッド

# %%
df = pd.DataFrame(data=np.random.randint(0, 5, 500), columns=['C1'])
df.head()
# Out:
#    C1
# 0   4
# 1   3
# 2   4
# 3   3
# 4   3

# %%
df['C1'].value_counts()
# Out:
# 1    128
# 4    108
# 0     99
# 3     93
# 2     72
# Name: C1, dtype: int64

# %%
plt.figure(figsize=(10, 10))
plt.pie(df['C1'].value_counts(), labels=df['C1'].value_counts().index)
plt.show()

# %% [markdown]
# # 見た目を整える

# %%
plt.figure(figsize=(10, 10))

textprops = {'fontsize': 20}

plt.pie(df['C1'].value_counts(), 
        labels=df['C1'].value_counts().index,
        autopct='%.1f%%',
        startangle=90, 
        counterclock=False,
        textprops=textprops)

plt.show()

# %% [markdown]
# # 箱ヒゲ図
#
#  boxplotメソッド

# %%
df = pd.DataFrame(data=np.random.randint(0, 100, 500), columns=['C1'])
df.head()
# Out:
#    C1
# 0  22
# 1  81
# 2  67
# 3  19
# 4  46

# %%
plt.figure(figsize=(12, 8))
plt.boxplot(df['C1'])
plt.show()

# %% [markdown]
# # 複数の箱ひげ図を描画

# %%
df = pd.DataFrame(data=np.random.rand(500, 5), columns=['C1', 'C2', 'C3', 'C4', 'C5'])
df.head()
# Out:
#          C1        C2        C3        C4        C5
# 0  0.646795  0.959833  0.202693  0.549358  0.842993
# 1  0.119473  0.990168  0.759613  0.248530  0.974775
# 2  0.228496  0.862971  0.246558  0.818504  0.326712
# 3  0.996199  0.814962  0.254663  0.761160  0.573728
# 4  0.232470  0.115879  0.444067  0.166811  0.842161

# %%
plt.figure(figsize=(12, 8))
plt.boxplot([df['C1'], df['C2'], df['C3'], df['C4'], df['C5']], labels=df.columns)
plt.show()

# %% [markdown]
# # ヒートマップ
#
# pcolorメソッド

# %%
df = pd.DataFrame(data=np.random.rand(5, 5), columns=['C1', 'C2', 'C3', 'C4', 'C5'])
df.head()
# Out:
#          C1        C2        C3        C4        C5
# 0  0.787051  0.916796  0.005719  0.518523  0.865272
# 1  0.715120  0.302892  0.688929  0.557263  0.709741
# 2  0.475131  0.958048  0.993604  0.981887  0.511339
# 3  0.827889  0.941835  0.878009  0.534764  0.995663
# 4  0.289295  0.963071  0.308351  0.575705  0.068944

# %%
plt.figure(figsize=(12, 8))
plt.pcolor(df, cmap='Blues')
plt.colorbar()
plt.show()

# %% [markdown]
# # スタイル
#
# seabornというライブラリを使うときれいに設定可

# %%
plt.style.use('ggplot')

x = np.linspace(0, 1, 10)
y = 2 * x + np.random.randn(10)

fig = plt.figure()
ax = fig.add_subplot(111) 

ax.plot(x, y) 

plt.show()

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
x = np.linspace(0, 1, 10)
y = 2 * x + np.random.randn(10)

fig = plt.figure()
ax = fig.add_subplot(111) 

ax.plot(x, y) 

plt.show()

# %% [markdown]
# # 画像ファイルとして出力
#
# savefigメソッド

# %%
x = np.linspace(0, 1, 10)
y = 2 * x + np.random.randn(10)

fig = plt.figure()
ax = fig.add_subplot(111) 

ax.plot(x, y) 

plt.savefig('test.png')
